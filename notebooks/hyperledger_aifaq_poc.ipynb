# %% [markdown]
# Install

# %%
# !git clone https://github.com/hyperledger-labs/aifaq --branch main --single-branch
# %cd /aifaq
# %pip install -r requirements.txt

# %% [markdown]
# Run

# %%
# !python src/app.py
